# %% [markdown]
# # SemanticDraw Streaming Pipeline Demo

# %% [markdown]
# ## Preparation

# %%
seed = 2024
device = 0

# %%
import sys
import time
import warnings

sys.path.append('../src')
warnings.filterwarnings('ignore')

import torch
import torchvision.transforms as T
from PIL import Image
from diffusers.utils import make_image_grid
from IPython.display import clear_output

from util import seed_everything, Streamer
from model import SemanticDraw


device = f'cuda:{device}'
seed_everything(seed)
print(f'[INFO] Initialized with seed  : {seed}')
print(f'[INFO] Initialized with device: {device}')

print('[INFO] Loading masks...') 
mask_all = Image.open('../assets/zeus/prompt.png').convert('RGBA')
mask_p1 = Image.open('../assets/zeus/prompt_p1.png').convert('RGBA')
mask_p2 = Image.open('../assets/zeus/prompt_p2.png').convert('RGBA')

mask_p1_t = T.ToTensor()(mask_p1)[-1:]
mask_p2_t = T.ToTensor()(mask_p2)[-1:]
background_t = torch.logical_and(mask_p1_t == 0, mask_p2_t == 0)

height, width = mask_p1_t.shape[-2:]
display(make_image_grid([mask_all, mask_p1, mask_p2], 1, 3))
# Out:
# [INFO] Initialized with seed  : 2024
# [INFO] Initialized with device: cuda:0
# [INFO] Loading masks...
# <PIL.Image.Image image mode=RGB size=1536x768>

# %% [markdown]
# # Run

# %% [markdown]
# ## Step 1: Load a SemanticDraw pipeline.

# %%
streamer = SemanticDraw(
    device,
    height=height,
    width=width,
    cfg_type="none",
    autoflush=True,
    use_tiny_vae=False,
    mask_type='continuous',
    bootstrap_steps=2,
    bootstrap_mix_steps=1.5,
    seed=seed,
)
# Out:
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# [INFO]     Loading Stable Diffusion...
# Loading checkpoint shards: 100%|██████████| 2/2 [00:00<00:00,  4.42it/s]
# Loading pipeline components...: 100%|██████████| 7/7 [00:00<00:00, 18.29it/s]
# [INFO]     Model is loaded!
# [INFO]     Parameters prepared!

# %% [markdown]
# ## Step 2: Register background image (white image is OK).

# %%
streamer.update_background(Image.new(size=(width, height), mode='RGB', color=(255, 255, 255)))
# Out:
# True

# %% [markdown]
# ## Step 3: Register *semantic palette*.
#
# Semantic palette is a list of pairs (text prompt, mask), which we call a *semantic brush/layer*. This is a basic unit of drawing in the multiple region-based text-to-image synthesis.

# %%
streamer.update_single_layer(
    idx=0,
    prompt='a photo of Mount Olympus',
    negative_prompt='worst quality, bad quality, normal quality, cropped, framed',
    mask=background_t,
    mask_strength=1.0,
    mask_std=0.0,
    prompt_strength=1.0,
)
streamer.update_single_layer(
    idx=1,
    prompt='Greek god Zeus looking at viewer',
    negative_prompt='worst quality, bad quality, normal quality, cropped, framed',
    mask=mask_p1_t,
    mask_strength=1.0,
    mask_std=0.0,
    prompt_strength=1.0,
)
streamer.update_single_layer(
    idx=2,
    prompt='a small, sitting eagle',
    negative_prompt='worst quality, bad quality, normal quality, cropped, framed',
    mask=mask_p2_t,
    mask_strength=1.0,
    mask_std=0.0,
    prompt_strength=1.0,
)

# %% [markdown]
# ## Step 4: Generate forever.

# %%
while True:
    display(streamer())
    time.sleep(0.2)
    clear_output()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 2
#       1 while True:
# ----> 2     display(streamer())
#       3     time.sleep(0.2)
#       4     clear_output()
#
# File ~/anaconda3/envs/semdraw/lib/python3.12/site-packages/torch/utils/_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File /mnt/ssd1/alchemist/workspace/cvpr25/semantic-draw/notebooks/../src/model/semantic_draw.py:1245, in SemanticDraw.__call__(self, no_decode, ignore_check_ready)
#    1242 if self.cfg_type in ('self', 'initialize'):
#    1243     self.stock_noise_ = self.stock_noise.repeat_interleave(self.num_layers, dim=0)  # (T * p, 77, 768)
# -> 1245 x_0_pred_batch = self.unet_step(latent)
#    1247 latent = x_0_pred_batch[-1:]
#    1248 self.x_t_latent_buffer = (
#    1249     self.alpha_prod_t_sqrt[1:] * x_0_pred_batch[:-1]
#    1250     + self.beta_prod_t_sqrt[1:] * self.init_noise[1:]
#    1251 )
#
# File /mnt/ssd1/alchemist/workspace/cvpr25/semantic-draw/notebooks/../src/model/semantic_draw.py:1151, in SemanticDraw.unet_step(self, x_t_latent, idx)
#    1140 model_pred = self.unet(
#    1141     x_t_latent_plus_uc,  # (B, 4, h, w)
#    1142     t_list,  # (B,)
#    (...)   1146     # added_cond_kwargs={'text_embeds': add_text_embeds, 'time_ids': add_time_ids},
#    1147 )[0]  # (B, 4, h, w)
#    1149 if self.bootstrap_steps[0] > 0:
#    1150     # Uncentering.
# -> 1151     bootstrap_mask = rearrange(self.masks, 'p t c h w -> (t p) c h w')
#    1152     if self.guidance_scale > 1.0 and self.cfg_type == 'initialize':
#    1153         bootstrap_mask_ = torch.concat([bootstrap_mask[:p], bootstrap_mask], dim=0)
#
# File ~/anaconda3/envs/semdraw/lib/python3.12/site-packages/einops/einops.py:545, in rearrange(tensor, pattern, **axes_lengths)
#     541         message += "Additional info: {}.".format(axes_lengths)
#     542         raise EinopsError(message + "\n {}".format(e))
# --> 545 def rearrange(tensor: Union[Tensor, List[Tensor]], pattern: str, **axes_lengths: Size) -> Tensor:
#     546     """
#     547     einops.rearrange is a reader-friendly smart element reordering for multidimensional tensors.
#     548     This operation includes functionality of transpose (axes permutation), reshape (view), squeeze, unsqueeze,
#    (...)    598
#     599     """
#     600     return reduce(tensor, pattern, reduction="rearrange", **axes_lengths)
#
# KeyboardInterrupt:
